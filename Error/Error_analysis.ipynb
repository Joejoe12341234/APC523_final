# %%
import numpy as np
import os

def compute_errors(sim_data, true_data):
    """Compute L2 and maximum errors between simulation and true data."""
    N_f = 51  # Define the number of points in the domain
    # Ensure data covers exactly N_f points. Adjust slicing or interpolation if necessary.
    
    print(sim_data.shape)
    print(true_data.shape)
    
    l2_error = np.sqrt(np.sum((sim_data - true_data) ** 2) / N_f)
    max_error = np.max(np.abs(sim_data - true_data))
    return l2_error, max_error

def main():

    reynolds_numbers = [10, 100]   
    timestep_methods = ['explicit_euler', 'projection']
    spatial_methods = ['QUICK', 'cdf2']
    fields = ['u', 'w', 'p']
    results = []

    # Loop through all combinations of settings
    for RE in reynolds_numbers:
        for timestep_method in timestep_methods:
            for spatial_method in spatial_methods:
                for field in fields:
                    
                    print(field, spatial_method, timestep_method, RE )
                    # True data filename pattern (modify path as needed)
                    if RE == 10:
                        true_filename = f'/Users/joelockwood/Downloads/APC523_final/assets/{field}-0.75s-Re_{RE}.0-space_cdf2-time_projection.npy'
                    else:
                        true_filename = f'/Users/joelockwood/Downloads/APC523_final/assets/{field}-3s-Re_{RE}.0-space_cdf2-time_projection.npy'
                    
                    if os.path.exists(true_filename):
                        true_data = np.load(true_filename)
                        print('Found', true_filename)

                        
                        sim_filename = f'output_error/{field}-0.75s-Re_{RE}-space_{spatial_method}-time_{timestep_method}.npy'
                        sim_data = np.load(sim_filename)
                        if sim_data.shape[0] > 50 or sim_data.shape[1] > 50:
                           sim_data = sim_data[:50, :50]  # Limit to 50x50
                        if true_data.shape[0] > 50 or sim_data.shape[1] > 50:
                            true_data = true_data[:50, :50]  # Limit to 50x50
                            
                        l2_error, max_error = compute_errors(sim_data, true_data)

                        result = {
                                'RE': RE,
                                'Timestep Method': timestep_method,
                                'Spatial Method': spatial_method,
                                'Field': field,
                                'L2 Error': l2_error,
                                'Maximum Error': max_error,
                                'Mean data': np.mean(sim_data)
                            }
                        results.append(result) 
                        
                        if os.path.exists(sim_filename):
                            print('Found', sim_filename)
                        else: 
                            print('Not found', {field}, {RE}, {spatial_method},{timestep_method} )
                            print('Not found', sim_filename)

    import pandas as pd

    # Create a DataFrame
    results_df = pd.DataFrame(results)

    # Save DataFrame to CSV file
    results_df.to_csv('output_error/error_analysis.csv', index=False)

    # Optionally, display the DataFrame
    print(results_df)

if __name__ == '__main__':
    main()
# Out:
# u QUICK explicit_euler 10
# Found /Users/joelockwood/Downloads/APC523_final/assets/u-0.75s-Re_10.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/u-0.75s-Re_10-space_QUICK-time_explicit_euler.npy
# w QUICK explicit_euler 10
# Found /Users/joelockwood/Downloads/APC523_final/assets/w-0.75s-Re_10.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/w-0.75s-Re_10-space_QUICK-time_explicit_euler.npy
# p QUICK explicit_euler 10
# Found /Users/joelockwood/Downloads/APC523_final/assets/p-0.75s-Re_10.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/p-0.75s-Re_10-space_QUICK-time_explicit_euler.npy
# u cdf2 explicit_euler 10
# Found /Users/joelockwood/Downloads/APC523_final/assets/u-0.75s-Re_10.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/u-0.75s-Re_10-space_cdf2-time_explicit_euler.npy
# w cdf2 explicit_euler 10
# Found /Users/joelockwood/Downloads/APC523_final/assets/w-0.75s-Re_10.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/w-0.75s-Re_10-space_cdf2-time_explicit_euler.npy
# p cdf2 explicit_euler 10
# Found /Users/joelockwood/Downloads/APC523_final/assets/p-0.75s-Re_10.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/p-0.75s-Re_10-space_cdf2-time_explicit_euler.npy
# u QUICK projection 10
# Found /Users/joelockwood/Downloads/APC523_final/assets/u-0.75s-Re_10.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/u-0.75s-Re_10-space_QUICK-time_projection.npy
# w QUICK projection 10
# Found /Users/joelockwood/Downloads/APC523_final/assets/w-0.75s-Re_10.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/w-0.75s-Re_10-space_QUICK-time_projection.npy
# p QUICK projection 10
# Found /Users/joelockwood/Downloads/APC523_final/assets/p-0.75s-Re_10.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/p-0.75s-Re_10-space_QUICK-time_projection.npy
# u cdf2 projection 10
# Found /Users/joelockwood/Downloads/APC523_final/assets/u-0.75s-Re_10.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/u-0.75s-Re_10-space_cdf2-time_projection.npy
# w cdf2 projection 10
# Found /Users/joelockwood/Downloads/APC523_final/assets/w-0.75s-Re_10.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/w-0.75s-Re_10-space_cdf2-time_projection.npy
# p cdf2 projection 10
# Found /Users/joelockwood/Downloads/APC523_final/assets/p-0.75s-Re_10.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/p-0.75s-Re_10-space_cdf2-time_projection.npy
# u QUICK explicit_euler 100
# Found /Users/joelockwood/Downloads/APC523_final/assets/u-3s-Re_100.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/u-0.75s-Re_100-space_QUICK-time_explicit_euler.npy
# w QUICK explicit_euler 100
# Found /Users/joelockwood/Downloads/APC523_final/assets/w-3s-Re_100.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/w-0.75s-Re_100-space_QUICK-time_explicit_euler.npy
# p QUICK explicit_euler 100
# Found /Users/joelockwood/Downloads/APC523_final/assets/p-3s-Re_100.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/p-0.75s-Re_100-space_QUICK-time_explicit_euler.npy
# u cdf2 explicit_euler 100
# Found /Users/joelockwood/Downloads/APC523_final/assets/u-3s-Re_100.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/u-0.75s-Re_100-space_cdf2-time_explicit_euler.npy
# w cdf2 explicit_euler 100
# Found /Users/joelockwood/Downloads/APC523_final/assets/w-3s-Re_100.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/w-0.75s-Re_100-space_cdf2-time_explicit_euler.npy
# p cdf2 explicit_euler 100
# Found /Users/joelockwood/Downloads/APC523_final/assets/p-3s-Re_100.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/p-0.75s-Re_100-space_cdf2-time_explicit_euler.npy
# u QUICK projection 100
# Found /Users/joelockwood/Downloads/APC523_final/assets/u-3s-Re_100.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/u-0.75s-Re_100-space_QUICK-time_projection.npy
# w QUICK projection 100
# Found /Users/joelockwood/Downloads/APC523_final/assets/w-3s-Re_100.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/w-0.75s-Re_100-space_QUICK-time_projection.npy
# p QUICK projection 100
# Found /Users/joelockwood/Downloads/APC523_final/assets/p-3s-Re_100.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/p-0.75s-Re_100-space_QUICK-time_projection.npy
# u cdf2 projection 100
# Found /Users/joelockwood/Downloads/APC523_final/assets/u-3s-Re_100.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/u-0.75s-Re_100-space_cdf2-time_projection.npy
# w cdf2 projection 100
# Found /Users/joelockwood/Downloads/APC523_final/assets/w-3s-Re_100.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/w-0.75s-Re_100-space_cdf2-time_projection.npy
# p cdf2 projection 100
# Found /Users/joelockwood/Downloads/APC523_final/assets/p-3s-Re_100.0-space_cdf2-time_projection.npy
# (50, 50)
# (50, 50)
# Found output_error/p-0.75s-Re_100-space_cdf2-time_projection.npy
#      RE Timestep Method Spatial Method Field   L2 Error  Maximum Error  \
# 0    10  explicit_euler          QUICK     u   0.042353       0.187001
# 1    10  explicit_euler          QUICK     w   0.042394       0.061506
# 2    10  explicit_euler          QUICK     p   0.123228       0.347233
# 3    10  explicit_euler           cdf2     u   0.041607       0.181026
# 4    10  explicit_euler           cdf2     w   0.047946       0.065963
# 5    10  explicit_euler           cdf2     p   0.101891       0.285407
# 6    10      projection          QUICK     u   0.039134       0.179264
# 7    10      projection          QUICK     w   0.046674       0.066563
# 8    10      projection          QUICK     p   0.133585       0.425233
# 9    10      projection           cdf2     u   0.040609       0.172254
# 10   10      projection           cdf2     w   0.053524       0.071103
# 11   10      projection           cdf2     p   0.111943       0.354704
# 12  100  explicit_euler          QUICK     u   1.296012       1.399132
# 13  100  explicit_euler          QUICK     w   1.368280       1.343235
# 14  100  explicit_euler          QUICK     p  28.584278      92.332996
# 15  100  explicit_euler           cdf2     u   1.339996       1.225801
# 16  100  explicit_euler           cdf2     w   1.533494       1.915328
# 17  100  explicit_euler           cdf2     p  19.091705      64.446048
# 18  100      projection          QUICK     u   1.314850       1.476548
# 19  100      projection          QUICK     w   1.391849       1.334603
# 20  100      projection          QUICK     p  28.701746      93.846185
# 21  100      projection           cdf2     u   1.363543       1.281227
# 22  100      projection           cdf2     w   1.566145       1.978912
# 23  100      projection           cdf2     p  19.288382      66.192495
#
#     Mean data
# 0    0.019761
# 1   -0.000015
# 2   -0.007623
# 3    0.018777
# 4   -0.000012
# 5   -0.007360
# 6    0.018784
# 7   -0.000012
# 8   -0.007456
# 9    0.017866
# 10  -0.000010
# 11  -0.007485
# 12   0.237841
# 13  -0.002560
# 14  -3.729885
# 15   0.229350
# 16  -0.002339
# 17  -3.199484
# 18   0.236436
# 19  -0.002477
# 20  -3.712347
# 21   0.227428
# 22  -0.002257
# 23  -3.199624
